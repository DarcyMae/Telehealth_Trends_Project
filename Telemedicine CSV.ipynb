# %%
import pandas as pd
import numpy as np

# %%
#Read in CSV
df_Telemedicine = pd.read_csv('./Resources/Telemedicine_Use_in_the_Last_4_Weeks_20240409.csv')
df_tmed_dy21 = pd.read_csv('./Resources/TMED_DY21_public_20220106.csv')
df_tmedtrend = pd.read_csv('./Resources/TMEDTREND_PUBLIC_240306.csv')

# %%
#Print DataFrame
df_Telemedicine.head()
# Out:
#                                            Indicator              Group  \
# 0  Adults Who Had Appointment with Health Profess...  National Estimate
# 1  Adults Who Had Appointment with Health Profess...             By Age
# 2  Adults Who Had Appointment with Health Profess...             By Age
# 3  Adults Who Had Appointment with Health Profess...             By Age
# 4  Adults Who Had Appointment with Health Profess...             By Age
#
#            State       Subgroup  Phase  Time Period      Time Period Label  \
# 0  United States  United States    3.1           28  Apr 14 - Apr 26, 2021
# 1  United States  18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021
# 2  United States  30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021
# 3  United States  40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021
# 4  United States  50 - 59 years    3.1           28  Apr 14 - Apr 26, 2021
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0             04/14/2021           04/26/2021   25.7    25.0     26.4
# 1             04/14/2021           04/26/2021   21.6    19.2     24.1
# 2             04/14/2021           04/26/2021   23.1    21.7     24.5
# 3             04/14/2021           04/26/2021   25.7    24.2     27.3
# 4             04/14/2021           04/26/2021   26.3    24.6     28.1
#
#   Confidence Interval Quartile Range  Suppression Flag
# 0         25.0 - 26.4            NaN               NaN
# 1         19.2 - 24.1            NaN               NaN
# 2         21.7 - 24.5            NaN               NaN
# 3         24.2 - 27.3            NaN               NaN
# 4         24.6 - 28.1            NaN               NaN

# %%
# Define a dictionary to map values
mapping_dict = {
    'Apr 14 - Apr 26, 2021': 17070, 
    'Apr 28 - May 10, 2021': 20047,
    'May 12 - May 24, 2021': 18658, 
    'May 26 - Jun 7, 2021': 17632,
    'Jun 9 - Jun 21, 2021': 17053, 
    'Jun 23 - Jul 5, 2021': 16639,
    'Jul 21 - Aug 2, 2021': 17373,
    'Aug 4 - Aug 16, 2021': 18655, 
    'Aug 18 - Aug 30, 2021': 18608,
    'Sep 1 - Sep 13, 2021': 16967, 
    'Sep 15 - Sep 27, 2021': 15724,
    'Sep 29 - Oct 11, 2021': 14738,  
    'Dec 1 - Dec 13, 2021': 15687, 
    'Dec 29, 2021 - Jan 10, 2022': 21371,
    'Jan 26 - Feb 7, 2022': 20542, 
    'Mar 2 - Mar 14, 2022': 21707, 
    'Mar 30 - Apr 11, 2022': 15943,
    'Apr 27 - May 9, 2022': 15156 , 
    'Jun 1 - Jun 13, 2022': 15766, 
    'Jun 29 - Jul 11, 2022': 14598,
    'Jul 27 - Aug 8, 2022': 1300
   
}

# Define a function to map values based on the dictionary
def map_values(label):
    return mapping_dict.get(label, None)

# Apply the function to create a new column
df_Telemedicine['Sample Size Households with Children'] = df_Telemedicine['Time Period Label'].apply(map_values)

df_Telemedicine.head()
# Out:
#                                            Indicator              Group  \
# 0  Adults Who Had Appointment with Health Profess...  National Estimate
# 1  Adults Who Had Appointment with Health Profess...             By Age
# 2  Adults Who Had Appointment with Health Profess...             By Age
# 3  Adults Who Had Appointment with Health Profess...             By Age
# 4  Adults Who Had Appointment with Health Profess...             By Age
#
#            State       Subgroup  Phase  Time Period      Time Period Label  \
# 0  United States  United States    3.1           28  Apr 14 - Apr 26, 2021
# 1  United States  18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021
# 2  United States  30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021
# 3  United States  40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021
# 4  United States  50 - 59 years    3.1           28  Apr 14 - Apr 26, 2021
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0             04/14/2021           04/26/2021   25.7    25.0     26.4
# 1             04/14/2021           04/26/2021   21.6    19.2     24.1
# 2             04/14/2021           04/26/2021   23.1    21.7     24.5
# 3             04/14/2021           04/26/2021   25.7    24.2     27.3
# 4             04/14/2021           04/26/2021   26.3    24.6     28.1
#
#   Confidence Interval Quartile Range  Suppression Flag  \
# 0         25.0 - 26.4            NaN               NaN
# 1         19.2 - 24.1            NaN               NaN
# 2         21.7 - 24.5            NaN               NaN
# 3         24.2 - 27.3            NaN               NaN
# 4         24.6 - 28.1            NaN               NaN
#
#    Sample Size Households with Children
# 0                               17070.0
# 1                               17070.0
# 2                               17070.0
# 3                               17070.0
# 4                               17070.0

# %%
# Define a dictionary to map values
mapping_dict = {
    'Apr 14 - Apr 26, 2021': 54835, 
    'Apr 28 - May 10, 2021': 62895,
    'May 12 - May 24, 2021': 58286, 
    'May 26 - Jun 7, 2021': 56436,
    'Jun 9 - Jun 21, 2021': 54267, 
    'Jun 23 - Jul 5, 2021': 52838,
    'Jul 21 - Aug 2, 2021': 55699,
    'Aug 4 - Aug 16, 2021': 59362, 
    'Aug 18 - Aug 30, 2021': 59705,
    'Sep 1 - Sep 13, 2021': 54950, 
    'Sep 15 - Sep 27, 2021': 51652,
    'Sep 29 - Oct 11, 2021': 49230,  
    'Dec 1 - Dec 13, 2021': 53078, 
    'Dec 29, 2021 - Jan 10, 2022': 67259,
    'Jan 26 - Feb 7, 2022': 66542, 
    'Mar 2 - Mar 14, 2022': 71848, 
    'Mar 30 - Apr 11, 2022': 54830,
    'Apr 27 - May 9, 2022': 52925 , 
    'Jun 1 - Jun 13, 2022': 53794, 
    'Jun 29 - Jul 11, 2022': 49637,
    'Jul 27 - Aug 8, 2022': 40180
   
}

# Define a function to map values based on the dictionary
def map_values(label):
    return mapping_dict.get(label, None)

# Apply the function to create a new column
df_Telemedicine['Sample Size Adult'] = df_Telemedicine['Time Period Label'].apply(map_values)

df_Telemedicine.head()
# Out:
#                                            Indicator              Group  \
# 0  Adults Who Had Appointment with Health Profess...  National Estimate
# 1  Adults Who Had Appointment with Health Profess...             By Age
# 2  Adults Who Had Appointment with Health Profess...             By Age
# 3  Adults Who Had Appointment with Health Profess...             By Age
# 4  Adults Who Had Appointment with Health Profess...             By Age
#
#            State       Subgroup  Phase  Time Period      Time Period Label  \
# 0  United States  United States    3.1           28  Apr 14 - Apr 26, 2021
# 1  United States  18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021
# 2  United States  30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021
# 3  United States  40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021
# 4  United States  50 - 59 years    3.1           28  Apr 14 - Apr 26, 2021
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0             04/14/2021           04/26/2021   25.7    25.0     26.4
# 1             04/14/2021           04/26/2021   21.6    19.2     24.1
# 2             04/14/2021           04/26/2021   23.1    21.7     24.5
# 3             04/14/2021           04/26/2021   25.7    24.2     27.3
# 4             04/14/2021           04/26/2021   26.3    24.6     28.1
#
#   Confidence Interval Quartile Range  Suppression Flag  \
# 0         25.0 - 26.4            NaN               NaN
# 1         19.2 - 24.1            NaN               NaN
# 2         21.7 - 24.5            NaN               NaN
# 3         24.2 - 27.3            NaN               NaN
# 4         24.6 - 28.1            NaN               NaN
#
#    Sample Size Households with Children  Sample Size Adult
# 0                               17070.0            54835.0
# 1                               17070.0            54835.0
# 2                               17070.0            54835.0
# 3                               17070.0            54835.0
# 4                               17070.0            54835.0

# %%
#Convert Date Columns to datetime
df_Telemedicine["Time Period Start Date"] = pd.to_datetime(
    df_Telemedicine["Time Period Start Date"],
    infer_datetime_format =True,
    utc = True
)
df_Telemedicine["Time Period End Date"] = pd.to_datetime(
    df_Telemedicine["Time Period End Date"],
    infer_datetime_format =True,
    utc = True
)
# Out:
# /var/folders/75/q6ncnq093g3_qnbg7m3pr7x00000gn/T/ipykernel_3408/970203181.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_Telemedicine["Time Period Start Date"] = pd.to_datetime(
# /var/folders/75/q6ncnq093g3_qnbg7m3pr7x00000gn/T/ipykernel_3408/970203181.py:7: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_Telemedicine["Time Period End Date"] = pd.to_datetime(

# %%
#Convert Dates to quarters
df_Telemedicine['quarters end period'] = df_Telemedicine["Time Period End Date"].dt.quarter
df_Telemedicine['quarters star period'] = df_Telemedicine["Time Period Start Date"].dt.quarter
Start_End_equal = df_Telemedicine['quarters end period']==df_Telemedicine['quarters star period']
any_false=(~Start_End_equal).any()  
print(any_false)
# Out:
# True

# %%
df_Telemedicine_quarters = df_Telemedicine.drop('quarters end period', axis=1).rename(columns={'quarters star period': 'Quarter'}).drop('Time Period End Date', axis=1)
df_Telemedicine_quarters['Time Period Start Date'] = df_Telemedicine_quarters["Time Period Start Date"].dt.year
df_tele_qtr_yr = df_Telemedicine_quarters.rename(columns={'Time Period Start Date': 'Year'})

# %%
df_tele_qtr_yr['State'].unique()
df_tele_qtr_yr.loc[df_tele_qtr_yr['State'] == 'United States', 'State'] = 'National'

# %%
df_tele_qtr_yr
# Out:
#                                               Indicator              Group  \
# 0     Adults Who Had Appointment with Health Profess...  National Estimate
# 1     Adults Who Had Appointment with Health Profess...             By Age
# 2     Adults Who Had Appointment with Health Profess...             By Age
# 3     Adults Who Had Appointment with Health Profess...             By Age
# 4     Adults Who Had Appointment with Health Profess...             By Age
# ...                                                 ...                ...
# 3339  Households With Children Where Any Child Had A...           By State
# 3340  Households With Children Where Any Child Had A...           By State
# 3341  Households With Children Where Any Child Had A...           By State
# 3342  Households With Children Where Any Child Had A...           By State
# 3343  Households With Children Where Any Child Had A...           By State
#
#               State       Subgroup  Phase  Time Period      Time Period Label  \
# 0          National  United States    3.1           28  Apr 14 - Apr 26, 2021
# 1          National  18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021
# 2          National  30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021
# 3          National  40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021
# 4          National  50 - 59 years    3.1           28  Apr 14 - Apr 26, 2021
# ...             ...            ...    ...          ...                    ...
# 3339       Virginia       Virginia    3.5           48   Jul 27 - Aug 8, 2022
# 3340     Washington     Washington    3.5           48   Jul 27 - Aug 8, 2022
# 3341  West Virginia  West Virginia    3.5           48   Jul 27 - Aug 8, 2022
# 3342      Wisconsin      Wisconsin    3.5           48   Jul 27 - Aug 8, 2022
# 3343        Wyoming        Wyoming    3.5           48   Jul 27 - Aug 8, 2022
#
#       Year  Value  Low CI  High CI Confidence Interval  \
# 0     2021   25.7    25.0     26.4         25.0 - 26.4
# 1     2021   21.6    19.2     24.1         19.2 - 24.1
# 2     2021   23.1    21.7     24.5         21.7 - 24.5
# 3     2021   25.7    24.2     27.3         24.2 - 27.3
# 4     2021   26.3    24.6     28.1         24.6 - 28.1
# ...    ...    ...     ...      ...                 ...
# 3339  2022   18.8    12.9     26.1         12.9 - 26.1
# 3340  2022   18.9    15.1     23.3         15.1 - 23.3
# 3341  2022    NaN     NaN      NaN                 NaN
# 3342  2022   13.8     8.8     20.3          8.8 - 20.3
# 3343  2022   10.7     6.6     16.2          6.6 - 16.2
#
#                  Quartile Range  Suppression Flag  \
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
# ...                         ...               ...
# 3339                  18.2-23.1               NaN
# 3340                  18.2-23.1               NaN
# 3341  Estimate is not reliable.               1.0
# 3342                  11.9-14.9               NaN
# 3343                   8.6-11.8               NaN
#
#       Sample Size Households with Children  Sample Size Adult  Quarter
# 0                                  17070.0            54835.0        2
# 1                                  17070.0            54835.0        2
# 2                                  17070.0            54835.0        2
# 3                                  17070.0            54835.0        2
# 4                                  17070.0            54835.0        2
# ...                                    ...                ...      ...
# 3339                                1300.0            40180.0        3
# 3340                                1300.0            40180.0        3
# 3341                                1300.0            40180.0        3
# 3342                                1300.0            40180.0        3
# 3343                                1300.0            40180.0        3
#
# [3344 rows x 17 columns]

# %%
df_tele_qtr_yr['Group'].unique()
# Out:
# array(['National Estimate', 'By Age', 'By Sex',
#        'By Race/Hispanic ethnicity', 'By Education',
#        'By Disability status', 'By State',
#        'By Education of adult respondent',
#        'By Race/Hispanic ethnicity of adult respondent',
#        'By Current US Armed Forces or National Guard service of adult respondent or spouse',
#        'By Health insurance of adult respondent',
#        'By Total household income', 'By Gender identity',
#        'By Sexual orientation'], dtype=object)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df_tele_qtr_yr["Year_Quarter"] = df_tele_qtr_yr['Year'].astype(str) + ' Q' + df_tele_qtr_yr['Quarter'].astype(str)


df_tele_qtr_yr.groupby('Year_Quarter').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Indicator vs Year_Quarter

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Year_Quarter'].value_counts()
    for x_label, grp in df_tele_qtr_yr.groupby('Indicator')
})



sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Indicator')
_ = plt.ylabel('Year_Quarter')

# %%
# @title Year_Quarter vs Time Period

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_tele_qtr_yr['Year_Quarter'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_tele_qtr_yr, x='Time Period', y='Year_Quarter', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as tick

df_tele_qtr_yr["Year_Quarter"] = df_tele_qtr_yr['Year'].astype(str) + ' Q' + df_tele_qtr_yr['Quarter'].astype(str)

tele_trend_recent = df_tele_qtr_yr.groupby('Year_Quarter')['Sample Size Adult'].sum()

fig, ax = plt.subplots(figsize=(14,7))
df_tele_qtr_yr.plot(kind="line", marker='o', ax=ax)

ax.yaxis.set_major_formatter(lambda x, pos: f'{x}')

plt.title('Trend of Telemedicine Over Time')
plt.ylabel('Total Telemedicine Beneficiaries')
plt.xlabel('Year and Quarter')
plt.grid('True')
plt.show()

# %%
plt.plot
# Example states
states_of_interest = ['New York', 'Illinois', 'California', 'Texas', 'Florida', 'Ohio'


# Plot the world average as a line chart
world_avg, = plt.plot(years, average_unemployment, color="blue", label="World Average" )

# Plot the unemployment values for a single country
country_one, = plt.plot(years, combined_unemployed_data.loc['USA',["2010","2011","2012","2013","2014","2015",
                                                                  "2016","2017","2018","2019","2020"]], 
                        color="green",label=combined_unemployed_data.loc['USA',"Country Name"])

# Create a legend for our chart
plt.legend(handles=[world_avg, country_one], loc="best")

# Show the chart
plt.show()

# %%
# Assuming 'df_tele_qtr_yr' is your DataFrame with relevant data
states_of_interest = ['New York', 'Illinois', 'California', 'Texas', 'Florida', 'Ohio']

# Grouping data
grouped_data = df_tele_qtr_yr.groupby(['State', 'Year_Quarter'])[['Sample Size Adult', 'Sample Size Households with Children']].sum().reset_index()

# Print grouped data for inspection
print("Grouped Data Sample:")
print(grouped_data.head())

# Plotting
fig, ax = plt.subplots(figsize=(14, 7))
legends_added = False

for state in states_of_interest:
    state_data = grouped_data[grouped_data['State'] == state]
    print(f"Data for {state}:")  # Debugging output
    print(state_data)            # Print state data to check contents
    if not state_data.empty:
        ax.plot(state_data['Year_Quarter'], state_data['Sample Size Adult'], marker='o', label=state)
        legends_added = True

if legends_added:
    ax.legend(title='State')
else:
    print("No data available for any of the specified states.")

ax.yaxis.set_major_formatter(tick.FuncFormatter(lambda y, _: f'{100 * y:.1f}%'))
ax.set_title('Trend of Telemedicine Use Across Most Populous States')
ax.set_xlabel('Year and Quarter')
ax.set_ylabel('Percentage of Telemedicine Beneficiaries (%)')
plt.xticks(rotation=45)
ax.grid(True)
plt.show()
# Out:
# Grouped Data Sample:
#      State Year_Quarter  Sample Size Adult  \
# 0  Alabama      2021 Q2           679114.0
# 1  Alabama      2021 Q3           661196.0
# 2  Alabama      2021 Q4           240674.0
# 3  Alabama      2022 Q1           386440.0
# 4  Alabama      2022 Q2           312712.0
#
#    Sample Size Households with Children
# 0                              214198.0
# 1                              204130.0
# 2                               74116.0
# 3                              116384.0
# 4                               91040.0
# Data for New York:
#         State Year_Quarter  Sample Size Adult  \
# 198  New York      2021 Q2           679114.0
# 199  New York      2021 Q3           661196.0
# 200  New York      2021 Q4           240674.0
# 201  New York      2022 Q1           386440.0
# 202  New York      2022 Q2           312712.0
# 203  New York      2022 Q3            80360.0
#
#      Sample Size Households with Children
# 198                              214198.0
# 199                              204130.0
# 200                               74116.0
# 201                              116384.0
# 202                               91040.0
# 203                                2600.0
# Data for Illinois:
#        State Year_Quarter  Sample Size Adult  \
# 78  Illinois      2021 Q2           679114.0
# 79  Illinois      2021 Q3           661196.0
# 80  Illinois      2021 Q4           240674.0
# 81  Illinois      2022 Q1           386440.0
# 82  Illinois      2022 Q2           312712.0
# 83  Illinois      2022 Q3            80360.0
#
#     Sample Size Households with Children
# 78                              214198.0
# 79                              204130.0
# 80                               74116.0
# 81                              116384.0
# 82                               91040.0
# 83                                2600.0
# Data for California:
#          State Year_Quarter  Sample Size Adult  \
# 24  California      2021 Q2           679114.0
# 25  California      2021 Q3           661196.0
# 26  California      2021 Q4           240674.0
# 27  California      2022 Q1           386440.0
# 28  California      2022 Q2           312712.0
# 29  California      2022 Q3            80360.0
#
#     Sample Size Households with Children
# 24                              214198.0
# 25                              204130.0
# 26                               74116.0
# 27                              116384.0
# 28                               91040.0
# 29                                2600.0
# Data for Texas:
#      State Year_Quarter  Sample Size Adult  \
# 264  Texas      2021 Q2           679114.0
# 265  Texas      2021 Q3           661196.0
# 266  Texas      2021 Q4           240674.0
# 267  Texas      2022 Q1           386440.0
# 268  Texas      2022 Q2           312712.0
# 269  Texas      2022 Q3            80360.0
#
#      Sample Size Households with Children
# 264                              214198.0
# 265                              204130.0
# 266                               74116.0
# 267                              116384.0
# 268                               91040.0
# 269                                2600.0
# Data for Florida:
#       State Year_Quarter  Sample Size Adult  \
# 54  Florida      2021 Q2           679114.0
# 55  Florida      2021 Q3           661196.0
# 56  Florida      2021 Q4           240674.0
# 57  Florida      2022 Q1           386440.0
# 58  Florida      2022 Q2           312712.0
# 59  Florida      2022 Q3            80360.0
#
#     Sample Size Households with Children
# 54                              214198.0
# 55                              204130.0
# 56                               74116.0
# 57                              116384.0
# 58                               91040.0
# 59                                2600.0
# Data for Ohio:
#     State Year_Quarter  Sample Size Adult  \
# 216  Ohio      2021 Q2           679114.0
# 217  Ohio      2021 Q3           661196.0
# 218  Ohio      2021 Q4           240674.0
# 219  Ohio      2022 Q1           386440.0
# 220  Ohio      2022 Q2           312712.0
# 221  Ohio      2022 Q3            80360.0
#
#      Sample Size Households with Children
# 216                              214198.0
# 217                              204130.0
# 218                               74116.0
# 219                              116384.0
# 220                               91040.0
# 221                                2600.0

# %%
# Example states
states_of_interest = ['New York', 'Illinois', 'California', 'Texas', 'Florida', 'Ohio']  # Example

# Grouping data
grouped_data = df_tele_qtr_yr.groupby(['State', 'Year_Quarter'])[['Sample Size Adult', 'Sample Size Households with Children']].sum().reset_index()
#grouped_data['Sample Size Adult'] = grouped_data['Sample Size Households with Children'] / grouped_data['Sample Size Households with Children']

# Plotting
fig, ax = plt.subplots(figsize=(14, 7))
legends_added = False

for state in states_of_interest:
    state_data = grouped_data[grouped_data['State'] == state]
    if not state_data.empty:
        ax.plot(state_data['Year_Quarter'], state_data['Sample Size Adult'], marker='o', label=state)
        legends_added = True

if legends_added:
    ax.legend(title='State')
else:
    print("No data available for any of the specified states.")

ax.yaxis.set_major_formatter(tick.FuncFormatter(lambda y, _: f'{100 * y:.1f}'))
ax.set_title('Trend of Telemedicine Use Across Most Populous States')
ax.set_xlabel('Year and Quarter')
ax.set_ylabel('Percentage of Telemedicine Beneficiaries (%)')
plt.xticks(rotation=45)
ax.grid(True)
plt.show()

# %%
df_tele_qtr_yr['State'].unique()
# Out:
# array(['National', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df_tele_qtr_yr_age = df_tele_qtr_yr[df_tele_qtr_yr['Group'] == 'By Age']

# %%
df_tele_qtr_yr['State'].unique()
# Out:
# array(['National', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df_tele_qtr_yr_age
# Out:
#                                               Indicator   Group     State  \
# 1     Adults Who Had Appointment with Health Profess...  By Age  National
# 2     Adults Who Had Appointment with Health Profess...  By Age  National
# 3     Adults Who Had Appointment with Health Profess...  By Age  National
# 4     Adults Who Had Appointment with Health Profess...  By Age  National
# 5     Adults Who Had Appointment with Health Profess...  By Age  National
# ...                                                 ...     ...       ...
# 3195  Adults Who Had Appointment with Health Profess...  By Age  National
# 3196  Adults Who Had Appointment with Health Profess...  By Age  National
# 3197  Adults Who Had Appointment with Health Profess...  By Age  National
# 3198  Adults Who Had Appointment with Health Profess...  By Age  National
# 3199  Adults Who Had Appointment with Health Profess...  By Age  National
#
#                 Subgroup  Phase  Time Period      Time Period Label  Year  \
# 1          18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021  2021
# 2          30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021  2021
# 3          40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021  2021
# 4          50 - 59 years    3.1           28  Apr 14 - Apr 26, 2021  2021
# 5          60 - 69 years    3.1           28  Apr 14 - Apr 26, 2021  2021
# ...                  ...    ...          ...                    ...   ...
# 3195       40 - 49 years    3.5           48   Jul 27 - Aug 8, 2022  2022
# 3196       50 - 59 years    3.5           48   Jul 27 - Aug 8, 2022  2022
# 3197       60 - 69 years    3.5           48   Jul 27 - Aug 8, 2022  2022
# 3198       70 - 79 years    3.5           48   Jul 27 - Aug 8, 2022  2022
# 3199  80 years and above    3.5           48   Jul 27 - Aug 8, 2022  2022
#
#       Value  Low CI  High CI Confidence Interval Quartile Range  \
# 1      21.6    19.2     24.1         19.2 - 24.1            NaN
# 2      23.1    21.7     24.5         21.7 - 24.5            NaN
# 3      25.7    24.2     27.3         24.2 - 27.3            NaN
# 4      26.3    24.6     28.1         24.6 - 28.1            NaN
# 5      27.6    25.9     29.4         25.9 - 29.4            NaN
# ...     ...     ...      ...                 ...            ...
# 3195   21.6    20.0     23.4         20.0 - 23.4            NaN
# 3196   24.4    22.5     26.4         22.5 - 26.4            NaN
# 3197   23.4    21.8     25.0         21.8 - 25.0            NaN
# 3198   28.8    26.6     31.0         26.6 - 31.0            NaN
# 3199   31.1    21.9     41.6         21.9 - 41.6            NaN
#
#       Suppression Flag  Quarter
# 1                  NaN        2
# 2                  NaN        2
# 3                  NaN        2
# 4                  NaN        2
# 5                  NaN        2
# ...                ...      ...
# 3195               NaN        3
# 3196               NaN        3
# 3197               NaN        3
# 3198               NaN        3
# 3199               NaN        3
#
# [175 rows x 15 columns]
