# %%
import pandas as pd
import numpy as np

# %%
df_Telemedicine = pd.read_csv('./Resources/Telemedicine_Use_in_the_Last_4_Weeks_20240409.csv')
df_tmed_dy21 = pd.read_csv('./Resources/TMED_DY21_public_20220106.csv')
df_tmedtrend = pd.read_csv('./Resources/TMEDTREND_PUBLIC_240306.csv')

# %%
#Print Data Frame
df_tmedtrend
# Out:
#        Year  quarter  Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus Bene_Race_Desc  \
# 0      2020  Overall       National                      All            All
# 1      2020  Overall       National                      All            All
# 2      2020  Overall       National                      All            All
# 3      2020  Overall       National                      All            All
# 4      2020  Overall       National                      All            All
# ...     ...      ...            ...                      ...            ...
# 21667  2023        3       Virginia                      All            All
# 21668  2023        3     Washington                      All            All
# 21669  2023        3  West Virginia                      All            All
# 21670  2023        3      Wisconsin                      All            All
# 21671  2023        3        Wyoming                      All            All
#
#       Bene_Sex_Desc Bene_Mdcr_Entlmt_Stus Bene_Age_Desc Bene_RUCA_Desc  \
# 0               All                   All           All            All
# 1               All                   All           All          Rural
# 2               All                   All           All          Urban
# 3               All                   All           All        Unknown
# 4               All                   All          0-64            All
# ...             ...                   ...           ...            ...
# 21667           All                   All           All        Unknown
# 21668           All                   All           All        Unknown
# 21669           All                   All           All        Unknown
# 21670           All                   All           All        Unknown
# 21671           All                   All           All        Unknown
#
#        Total_Bene_TH_Elig  Total_PartB_Enrl  Total_Bene_Telehealth  \
# 0              30946785.0      3.224489e+07             14826919.0
# 1               7179538.0      7.490301e+06              2858284.0
# 2              23696871.0      2.462914e+07             11944230.0
# 3                     NaN               NaN                    NaN
# 4               4088345.0      4.291403e+06              2322324.0
# ...                   ...               ...                    ...
# 21667                 NaN               NaN                    NaN
# 21668                 NaN               NaN                    NaN
# 21669                 NaN               NaN                    NaN
# 21670                 NaN               NaN                    NaN
# 21671                 NaN               NaN                    NaN
#
#        Pct_Telehealth
# 0              0.4791
# 1              0.3981
# 2              0.5040
# 3                 NaN
# 4              0.5680
# ...               ...
# 21667             NaN
# 21668             NaN
# 21669             NaN
# 21670             NaN
# 21671             NaN
#
# [21672 rows x 13 columns]

# %%
#Check Types
df_tmedtrend.dtypes
# Out:
# Year                          int64
# quarter                      object
# Bene_Geo_Desc                object
# Bene_Mdcd_Mdcr_Enrl_Stus     object
# Bene_Race_Desc               object
# Bene_Sex_Desc                object
# Bene_Mdcr_Entlmt_Stus        object
# Bene_Age_Desc                object
# Bene_RUCA_Desc               object
# Total_Bene_TH_Elig          float64
# Total_PartB_Enrl            float64
# Total_Bene_Telehealth       float64
# Pct_Telehealth              float64
# dtype: object

# %%
#Check Unique Values in Quarters Column
df_tmedtrend['quarter'].unique()

#Check value count of Overall
overall_count = df_tmedtrend['quarter'].value_counts().get('Overall', 0)
print(overall_count)

#Filter out Overall
filtered_qtr_tmedtrend = df_tmedtrend.query("quarter != 'Overall'")
# Out:
# 3612

# %%
#Rename Columns
filtered_qtr_tmedtrend=filtered_qtr_tmedtrend.rename(columns={'Bene_Geo_Desc': 'State'}).rename(columns={'quarter': 'Quarter'}).rename(columns={'Bene_Age_Desc': 'Age'})

# %%
#Check unique values in Age column
filtered_qtr_tmedtrend['Age'].unique()
# Out:
# array(['All', '0-64', '65-74', '75-84', '85 and over'], dtype=object)

# %%
#Filter out All
filtered_qtr_age_tmedtrend = filtered_qtr_tmedtrend[filtered_qtr_tmedtrend['Age'] != 'All']

filtered_qtr_age_tmedtrend['Age'].unique()
# Out:
# array(['0-64', '65-74', '75-84', '85 and over'], dtype=object)

# %%
filtered_qtr_age_tmedtrend
# Out:
#        Year Quarter      State Bene_Mdcd_Mdcr_Enrl_Stus  \
# 1270   2020       1   National                      All
# 1271   2020       1   National      Medicare & Medicaid
# 1272   2020       1   National            Medicare Only
# 1273   2020       1   National                      All
# 1274   2020       1   National                      All
# ...     ...     ...        ...                      ...
# 21496  2023       3  Wisconsin                      All
# 21513  2023       3    Wyoming                      All
# 21514  2023       3    Wyoming                      All
# 21515  2023       3    Wyoming                      All
# 21516  2023       3    Wyoming                      All
#
#                       Bene_Race_Desc Bene_Sex_Desc Bene_Mdcr_Entlmt_Stus  \
# 1270                             All           All                   All
# 1271                             All           All                   All
# 1272                             All           All                   All
# 1273   American Indian/Alaska Native           All                   All
# 1274          Asian/Pacific Islander           All                   All
# ...                              ...           ...                   ...
# 21496                            All           All                   All
# 21513                            All           All                   All
# 21514                            All           All                   All
# 21515                            All           All                   All
# 21516                            All           All                   All
#
#                Age Bene_RUCA_Desc  Total_Bene_TH_Elig  Total_PartB_Enrl  \
# 1270          0-64            All           3163071.0      4.301853e+06
# 1271          0-64            All           2012704.0      2.571352e+06
# 1272          0-64            All           1150367.0      1.730500e+06
# 1273          0-64            All             37085.0      4.961333e+04
# 1274          0-64            All             58292.0      8.433633e+04
# ...            ...            ...                 ...               ...
# 21496  85 and over            All             41593.0      5.168267e+04
# 21513         0-64            All              5754.0      8.414667e+03
# 21514        65-74            All             33249.0      5.183133e+04
# 21515        75-84            All             21050.0      2.849067e+04
# 21516  85 and over            All              7328.0      9.206000e+03
#
#        Total_Bene_Telehealth  Pct_Telehealth
# 1270                365839.0          0.1157
# 1271                251094.0          0.1248
# 1272                114745.0          0.0997
# 1273                  3493.0          0.0942
# 1274                  6026.0          0.1034
# ...                      ...             ...
# 21496                 2529.0          0.0608
# 21513                  959.0          0.1667
# 21514                 1750.0          0.0526
# 21515                 1042.0          0.0495
# 21516                  327.0          0.0446
#
# [3600 rows x 13 columns]
